# %%
keyboard = [range(1, 3), range(4, 6), range(7, 9)]
initial = 5

keyboard[1][1]

from numpy import genfromtxt
steps = genfromtxt('input.txt', delimiter=',', dtype='str', autostrip=True)

# %%
list(steps[0])
# Out:
# ['U',
#  'R',
#  'U',
#  'L',
#  'L',
#  'L',
#  'L',
#  'L',
#  'R',
#  'L',
#  'D',
#  'D',
#  'U',
#  'U',
#  'R',
#  'R',
#  'R',
#  'U',
#  'L',
#  'L',
#  'L',
#  'D',
#  'U',
#  'R',
#  'R',
#  'D',
#  'R',
#  'D',
#  'R',
#  'D',
#  'L',
#  'U',
#  'R',
#  'U',
#  'R',
#  'U',
#  'R',
#  'L',
#  'D',
#  'L',
#  'L',
#  'L',
#  'L',
#  'R',
#  'U',
#  'D',
#  'D',
#  'R',
#  'R',
#  'L',
#  'U',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'L',
#  'R',
#  'L',
#  'R',
#  'D',
#  'D',
#  'D',
#  'U',
#  'U',
#  'D',
#  'U',
#  'D',
#  'L',
#  'D',
#  'U',
#  'L',
#  'U',
#  'D',
#  'L',
#  'D',
#  'U',
#  'R',
#  'D',
#  'U',
#  'L',
#  'L',
#  'R',
#  'D',
#  'D',
#  'U',
#  'R',
#  'L',
#  'L',
#  'L',
#  'R',
#  'R',
#  'R',
#  'L',
#  'L',
#  'R',
#  'U',
#  'R',
#  'L',
#  'L',
#  'U',
#  'D',
#  'R',
#  'D',
#  'L',
#  'L',
#  'R',
#  'R',
#  'L',
#  'D',
#  'D',
#  'R',
#  'U',
#  'D',
#  'U',
#  'L',
#  'R',
#  'R',
#  'D',
#  'D',
#  'L',
#  'U',
#  'U',
#  'U',
# ...

# %%
['a', 'b'].join()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-457c31881c31> in <module>()
# ----> 1 ['a', 'b'].join()
#
# AttributeError: 'list' object has no attribute 'join'

# %%
[x + y for x, y in zip([0, 1], [2, 0])]
# Out:
# [2, 1]

# %%
a = keyboard[0]

# %%
len(keyboard)
# Out:
# 3
